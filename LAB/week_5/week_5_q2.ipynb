# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten
import matplotlib.pyplot as plt
# Out:
# 2023-09-04 10:12:31.131365: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-09-04 10:12:31.156654: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-04 10:12:31.563789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.read_csv('GOOGL.csv')
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    50.050049    52.082081    48.028027    50.220219
# 1     2004-08-20    50.555557    54.594597    50.300301    54.209209
# 2     2004-08-23    55.430431    56.796799    54.579578    54.754753
# 3     2004-08-24    55.675674    55.855858    51.836838    52.487488
# 4     2004-08-25    52.532532    54.054054    51.991993    53.053055
# ...          ...          ...          ...          ...          ...
# 4426  2022-03-18  2668.489990  2724.879883  2645.169922  2722.510010
# 4427  2022-03-21  2723.270020  2741.000000  2681.850098  2722.030029
# 4428  2022-03-22  2722.030029  2821.000000  2722.030029  2797.360107
# 4429  2022-03-23  2774.050049  2791.770020  2756.699951  2765.510010
# 4430  2022-03-24  2784.000000  2832.379883  2755.010010  2831.439941
#
#         Adj Close    Volume
# 0       50.220219  44659096
# 1       54.209209  22834343
# 2       54.754753  18256126
# 3       52.487488  15247337
# 4       53.053055   9188602
# ...           ...       ...
# 4426  2722.510010   2223100
# 4427  2722.030029   1341600
# 4428  2797.360107   1774800
# 4429  2765.510010   1257700
# 4430  2831.439941   1317900
#
# [4431 rows x 7 columns]

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2004-08-19    50.050049    52.082081    48.028027    50.220219
# 1    2004-08-20    50.555557    54.594597    50.300301    54.209209
# 2    2004-08-23    55.430431    56.796799    54.579578    54.754753
# 3    2004-08-24    55.675674    55.855858    51.836838    52.487488
# 4    2004-08-25    52.532532    54.054054    51.991993    53.053055
# ...         ...          ...          ...          ...          ...
# 4426 2022-03-18  2668.489990  2724.879883  2645.169922  2722.510010
# 4427 2022-03-21  2723.270020  2741.000000  2681.850098  2722.030029
# 4428 2022-03-22  2722.030029  2821.000000  2722.030029  2797.360107
# 4429 2022-03-23  2774.050049  2791.770020  2756.699951  2765.510010
# 4430 2022-03-24  2784.000000  2832.379883  2755.010010  2831.439941
#
#         Adj Close    Volume
# 0       50.220219  44659096
# 1       54.209209  22834343
# 2       54.754753  18256126
# 3       52.487488  15247337
# 4       53.053055   9188602
# ...           ...       ...
# 4426  2722.510010   2223100
# 4427  2722.030029   1341600
# 4428  2797.360107   1774800
# 4429  2765.510010   1257700
# 4430  2831.439941   1317900
#
# [4431 rows x 7 columns]

# %%
df = df.loc[:,["High"]].values
train = df[:len(df)-50] 
test = df[len(train):]

# %%
train = train.reshape(train.shape[0],1)

# %%
plt.plot(train);
plt.title("High prices for the data")
# Out:
# Text(0.5, 1.0, 'High prices for the data')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0,1))
train_scaled = scaler.fit_transform(train)

# %%
import numpy as np
X_train = []
y_train = []
timesteps = 50

for i in range(timesteps, train_scaled.shape[0]):
    X_train.append(train_scaled[i-timesteps:i,0])
    y_train.append(train_scaled[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# %%
from keras.layers import SimpleRNN
from keras.layers import Dropout

regressor = Sequential()

regressor.add(SimpleRNN(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2)) 

regressor.add(SimpleRNN(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
 
regressor.add(SimpleRNN(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 2023-09-04 10:12:34.360925: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.376771: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.376915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.378068: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.378163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.378229: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.699753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.699888: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.699955: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-04 10:12:34.700016: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4397 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2023-09-04 10:12:36.142132: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e754d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-09-04 10:12:36.142152: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2023-09-04 10:12:36.145037: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-09-04 10:12:36.224809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2023-09-04 10:12:36.282044: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 136/136 [==============================] - 5s 24ms/step - loss: 0.0943
# Epoch 2/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0499
# Epoch 3/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0467
# Epoch 4/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0454
# Epoch 5/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0448
# Epoch 6/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0444
# Epoch 7/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0442
# Epoch 8/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0440
# Epoch 9/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0440
# Epoch 10/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0439
# Epoch 11/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0439
# Epoch 12/100
# 136/136 [==============================] - 3s 25ms/step - loss: 0.0438
# Epoch 13/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0437
# Epoch 14/100
# 136/136 [==============================] - 3s 25ms/step - loss: 0.0437
# Epoch 15/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 16/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0436
# Epoch 17/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0436
# Epoch 18/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 19/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 20/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 21/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 22/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0435
# Epoch 23/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0436
# Epoch 24/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 25/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 26/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 27/100
# 136/136 [==============================] - 3s 25ms/step - loss: 0.0434
# Epoch 28/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 29/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0434
# Epoch 30/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 31/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0434
# Epoch 32/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0434
# Epoch 33/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 34/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 35/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0434
# Epoch 36/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0433
# Epoch 37/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 38/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 39/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 40/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 41/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 42/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 43/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 44/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 45/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 46/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 47/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 48/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0434
# Epoch 49/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 50/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 51/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 52/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 53/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 54/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 55/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 56/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 57/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 58/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 59/100
# 136/136 [==============================] - 3s 23ms/step - loss: 0.0432
# Epoch 60/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 61/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 62/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 63/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 64/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 65/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 66/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 67/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 68/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 69/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 70/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 71/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 72/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 73/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 74/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 75/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 76/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 77/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 78/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 79/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 80/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 81/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 82/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 83/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 84/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 85/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 86/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 87/100
# 136/136 [==============================] - 3s 25ms/step - loss: 0.0432
# Epoch 88/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 89/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 90/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 91/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 92/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 93/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 94/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0433
# Epoch 95/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 96/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 97/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 98/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 99/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
# Epoch 100/100
# 136/136 [==============================] - 3s 24ms/step - loss: 0.0432
